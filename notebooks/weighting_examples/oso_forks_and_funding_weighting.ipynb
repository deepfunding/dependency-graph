# %%
from collections import defaultdict, Counter
import json
import networkx as nx
import numpy as np
import os
import pandas as pd
import sys

sys.path.append(os.path.abspath("../.."))
from utils.validate_weights import validate_weights
from utils.serialize_graph import convert_graph_to_serializable

# %% [markdown]
# # Load the unweighted graph

# %%
with open('../../graph/unweighted_graph.json', 'r') as f:
    graph_data = json.load(f)

G = nx.node_link_graph(graph_data)
print("Nodes:", len(G.nodes))
repo_urls = [x for x in G.nodes]
print("Edges:", len(G.edges))
# Out:
# Nodes: 4303
# Edges: 9896

# %%
validate_weights(G)
# Out:
# {'https://github.com/ethereum/solidity': 0.0,
#  'https://github.com/vyperlang/vyper': 0.0,
#  'https://github.com/ethereum/py-evm': 0.0,
#  'https://github.com/ethereum/web3.py': 0.0,
#  'https://github.com/paradigmxyz/reth': 0.0,
#  'https://github.com/consensys/teku': 0.0,
#  'https://github.com/prysmaticlabs/prysm': 0.0,
#  'https://github.com/erigontech/erigon': 0.0,
#  'https://github.com/web3/web3.js': 0.0,
#  'https://github.com/grandinetech/grandine': 0.0,
#  'https://github.com/chainsafe/lodestar': 0.0,
#  'https://github.com/sigp/lighthouse': 0.0,
#  'https://github.com/ethereum/go-ethereum': 0.0,
#  'https://github.com/status-im/nimbus-eth2': 0.0,
#  'https://github.com/ethereum/remix-project': 0.0,
#  'https://github.com/safe-global/safe-smart-account': 0.0,
#  'https://github.com/eth-infinitism/account-abstraction': 0.0,
#  'https://github.com/ethereumjs/ethereumjs-monorepo': 0.0}

# %%
relations = [data['relation'] for _, _, data in G.edges(data=True) if 'relation' in data]
pkg_relation_counts = Counter(relations)
pkg_relation_counts
# Out:
# Counter({'NPM': 7814, 'RUST': 1349, 'GO': 598, 'PIP': 135})

# %% [markdown]
# # Grab some repo-level and historical funding data
#
# - Subscribe to the OSO Production dataset on BigQuery (see docs [here](https://docs.opensource.observer/docs/get-started/bigquery))
# - Enter the following query into your [console](https://console.cloud.google.com/bigquery) to get a fresh copy of the graph
# - Save it as a CSV file to `datasets/oso/repo_and_funding_stats.csv`

# %%
def stringify_array(arr):
    return "'" + "','".join(arr) + "'"

query = f"""
    -- COPY THIS INTO YOUR BIGQUERY CONSOLE

    with repos as (
      select
        project_id as oso_project_id,
        artifact_url as url,
        is_fork,
        star_count,
        fork_count,
        license_name,
        language,
        created_at,
        updated_at
      from `oso.repositories_v0`
    ),

    gitcoin as (
      select
        oso_project_id,
        sum(amount_in_usd) as gitcoin_grants_usd,
        count(distinct donor_address) as unique_donors,
        count(distinct round_number) as num_rounds
      from `oso.gitcoin_funding_events_by_project_v0`
      where oso_project_id is not null and donor_address is not null
      group by oso_project_id
    ),

    retrofunding as (
      select
        p.project_id,
        sum(f.amount) as retro_funding_usd,
        count(distinct f.grant_pool_name) as num_retro_funding_rounds
      from `static_data_sources.oss_funding_v1` f
      join `oso.projects_v1` p
        on f.to_project_name = p.project_name
      where
        f.grant_pool_name like '%retro%'
        and f.from_funder_name = 'optimism'
      group by p.project_id
    )

    select
      repos.url,
      repos.star_count,
      repos.fork_count,
      repos.is_fork,
      repos.language,
      repos.license_name,
      repos.created_at,
      repos.updated_at,
      coalesce(gitcoin.gitcoin_grants_usd, 0) as gitcoin_grants_usd,
      coalesce(gitcoin.unique_donors, 0) as gitcoin_unique_donors,
      coalesce(gitcoin.num_rounds, 0) as gitcoin_num_rounds,
      coalesce(retrofunding.retro_funding_usd, 0) as retro_funding_usd,
      coalesce(retrofunding.num_retro_funding_rounds, 0) as num_retro_funding_rounds,
      repos.oso_project_id
    from repos
    left join gitcoin
      on repos.oso_project_id = gitcoin.oso_project_id
    left join retrofunding
      on repos.oso_project_id = retrofunding.project_id
    
    -- Add the list of relevant repo_urls as a where clause
"""
#query += f"    where url in ({stringify_array(repo_urls)})"
print(query)
# Out:
#     -- COPY THIS INTO YOUR BIGQUERY CONSOLE
#
#     with repos as (
#       select
#         project_id as oso_project_id,
#         artifact_url as url,
#         is_fork,
#         star_count,
#         fork_count,
#         license_name,
#         language,
#         created_at,
#         updated_at
#       from `oso.repositories_v0`
#     ),
#
#     gitcoin as (
#       select
#         oso_project_id,
#         sum(amount_in_usd) as gitcoin_grants_usd,
#         count(distinct donor_address) as unique_donors,
#         count(distinct round_number) as num_rounds
#       from `oso.gitcoin_funding_events_by_project_v0`
#       where oso_project_id is not null and donor_address is not null
#       group by oso_project_id
#     ),
#
#     retrofunding as (
#       select
#         p.project_id,
#         sum(f.amount) as retro_funding_usd,
#         count(distinct f.grant_pool_name) as num_retro_funding_rounds
#       from `static_data_sources.oss_funding_v1` f
#       join `oso.projects_v1` p
#         on f.to_project_name = p.project_name
#       where
#         f.grant_pool_name like '%retro%'
#         and f.from_funder_name = 'optimism'
#       group by p.project_id
#     )
#
#     select
#       repos.url,
#       repos.star_count,
#       repos.fork_count,
#       repos.is_fork,
#       repos.language,
#       repos.license_name,
#       repos.created_at,
#       repos.updated_at,
#       coalesce(gitcoin.gitcoin_grants_usd, 0) as gitcoin_grants_usd,
#       coalesce(gitcoin.unique_donors, 0) as gitcoin_unique_donors,
#       coalesce(gitcoin.num_rounds, 0) as gitcoin_num_rounds,
#       coalesce(retrofunding.retro_funding_usd, 0) as retro_funding_usd,
#       coalesce(retrofunding.num_retro_funding_rounds, 0) as num_retro_funding_rounds,
#       repos.oso_project_id
#     from repos
#     left join gitcoin
#       on repos.oso_project_id = gitcoin.oso_project_id
#     left join retrofunding
#       on repos.oso_project_id = retrofunding.project_id
#
#     -- Add the list of relevant repo_urls as a where clause

# %%
# load the data and transform it a bit
metrics_df = pd.read_csv('../../datasets/oso/repo_and_funding_stats.csv', index_col=0)

funding_averages = (
    metrics_df
    .groupby('oso_project_id')
    [['gitcoin_grants_usd', 'retro_funding_usd']]
    .transform('mean')
)
metrics_df['gitcoin_grants_usd'] = funding_averages['gitcoin_grants_usd']
metrics_df['retro_funding_usd'] = funding_averages['retro_funding_usd']

print("Metric totals:")
for c in metrics_df.columns:
    if metrics_df[c].dtype != 'O':
        print(f"- {c}: {metrics_df[c].sum():,.0f}")
        
metrics_df.tail(1).T
# Out:
# Metric totals:
# - star_count: 4,290,460
# - fork_count: 629,244
# - is_fork: 28
# - gitcoin_grants_usd: 1,993,910
# - gitcoin_unique_donors: 266,906
# - gitcoin_num_rounds: 308
# - retro_funding_usd: 66,773,465
# - num_retro_funding_rounds: 142
# url                      https://github.com/dalek-cryptography/x25519-dalek
# star_count                                                              331
# fork_count                                                              133
# is_fork                                                               False
# language                                                               Rust
# license_name                        BSD 3-Clause "New" or "Revised" License
# created_at                                   2017-09-12 22:14:24.000000 UTC
# updated_at                                   2024-11-15 09:48:21.000000 UTC
# gitcoin_grants_usd                                                      0.0
# gitcoin_unique_donors                                                     0
# gitcoin_num_rounds                                                        0
# retro_funding_usd                                                       0.0
# num_retro_funding_rounds                                                  0
# oso_project_id                 2M40Vo4_rK8jXTpEvF2Nn3iShhpkzNVhssGAAQJnwR4=

# %%
# add these variables as attributes in our graph

for node in G.nodes():
    if node in metrics_df.index:
        for col in metrics_df.columns:
            G.nodes[node][col] = metrics_df.at[node, col]
    else:
        for col in metrics_df.columns:
            G.nodes[node][col] = 0

sample_node = list(G.nodes())[4]
attrs = G.nodes[sample_node]
print("Node attributes for", sample_node)
for k,v in attrs.items():
    print(f"-{k}: {v}")
# Out:
# Node attributes for https://github.com/paradigmxyz/reth
# -level: 1
# -star_count: 4055
# -fork_count: 1265
# -is_fork: False
# -language: Rust
# -license_name: Apache License 2.0
# -created_at: 2022-09-15 23:05:57.000000 UTC
# -updated_at: 2024-12-14 23:26:11.000000 UTC
# -gitcoin_grants_usd: 0.0
# -gitcoin_unique_donors: 0
# -gitcoin_num_rounds: 0
# -retro_funding_usd: 795399.697879558
# -num_retro_funding_rounds: 2
# -oso_project_id: tgh4Nfzx1PGlz2i8zMrbHi9DuPLpQUnmtVqYZ7v83Fo=

# %% [markdown]
# # Apply a basic weighting algorithm

# %%
total_weight_cap = 0.8
max_edge_weight = 0.2

max_gitcoin = max(nx.get_node_attributes(G, 'gitcoin_grants_usd').values(), default=1)
max_retro = max(nx.get_node_attributes(G, 'retro_funding_usd').values(), default=1)
max_forks = max(nx.get_node_attributes(G, 'fork_count').values(), default=1)

for seed_node, node_data in G.nodes(data=True):
    if node_data.get('level') != 1:
        continue

    dependents = list(G.successors(seed_node))
    weights = []

    # Step 1: Calculate raw weights with language check
    for dep in dependents:
        seed_language = G.nodes[seed_node].get('language', None)
        if seed_language in ['JavaScript', 'TypeScript', 'Python', 'Rust', 'Go']:
            dep_language = G.nodes[dep].get('language', None)
            if seed_language != dep_language:
                weights.append((dep, 0.0))
                continue

        gitcoin = G.nodes[dep].get('gitcoin_grants_usd', 0) / max_gitcoin
        retro = G.nodes[dep].get('retro_funding_usd', 0) / max_retro
        forks = G.nodes[dep].get('fork_count', 0)
        if forks:
            forks = np.log(forks) / np.log(max_forks)

        raw_weight = 0.4 * gitcoin + 0.4 * retro + 0.2 * forks
        weights.append((dep, raw_weight))

    total_raw_weight = sum(w for _, w in weights)

    # Step 2: Normalize raw weights
    normalized_weights = [
        (dep, (w / total_raw_weight) * total_weight_cap) if total_raw_weight > 0 else (dep, 0.0)
        for dep, w in weights
    ]

    # Step 3: Cap weights and calculate remaining weight
    capped_weights = []
    remaining_weight = total_weight_cap

    for dep, weight in normalized_weights:
        capped_weight = min(weight, max_edge_weight)
        capped_weights.append((dep, capped_weight))
        remaining_weight -= capped_weight

    # Step 4: Redistribute remaining weight proportionally to uncapped edges
    uncapped_edges = [(dep, weight) for dep, weight in capped_weights if weight < max_edge_weight]
    uncapped_total = sum(weight for _, weight in uncapped_edges)

    final_weights = []
    for dep, capped_weight in capped_weights:
        if uncapped_total > 0 and capped_weight < max_edge_weight:
            additional_weight = (capped_weight / uncapped_total) * remaining_weight
            new_weight = min(capped_weight + additional_weight, max_edge_weight)
            final_weights.append((dep, new_weight))
        else:
            final_weights.append((dep, capped_weight))

    # Step 5: Assign weights back to edges
    for dep, weight in final_weights:
        if G.has_edge(seed_node, dep):
            G[seed_node][dep]['weight'] = weight

# %%
for seed_node in G.nodes():
    outgoing_edges = [(v, G[seed_node][v]['weight']) for v in G.successors(seed_node) 
                      if 'weight' in G[seed_node][v]]
    sorted_edges = sorted(outgoing_edges, key=lambda x: x[1], reverse=True)
    if sorted_edges:
        total_weights = sum([x[1] for x in sorted_edges])
        print(f"\nSeed Node: {seed_node} | Weight: {1 - total_weights:.4f}")
        for i, (dep, weight) in enumerate(sorted_edges):
            if i < 10:
                print(f"- Dependent: {dep} | Weight: {weight:.4f}")
# Out:
# Seed Node: https://github.com/ethereum/solidity | Weight: 1.0000
# - Dependent: https://github.com/taminomara/sphinx-a4doc | Weight: 0.0000
# - Dependent: https://github.com/sphinx-doc/sphinx | Weight: 0.0000
# - Dependent: https://github.com/readthedocs/sphinx_rtd_theme | Weight: 0.0000
#
# Seed Node: https://github.com/vyperlang/vyper | Weight: 1.0000
# - Dependent: https://github.com/pypa/wheel | Weight: 0.0000
# - Dependent: https://github.com/pypa/packaging | Weight: 0.0000
# - Dependent: https://github.com/gristlabs/asttokens | Weight: 0.0000
# - Dependent: https://github.com/lepture/shibuya | Weight: 0.0000
# - Dependent: https://github.com/agronholm/cbor2 | Weight: 0.0000
# - Dependent: https://github.com/legrandin/pycryptodome | Weight: 0.0000
# - Dependent: https://github.com/python/importlib_metadata | Weight: 0.0000
# - Dependent: https://github.com/executablebooks/sphinx-copybutton | Weight: 0.0000
# - Dependent: https://github.com/sphinx-doc/sphinx | Weight: 0.0000
#
# Seed Node: https://github.com/ethereum/py-evm | Weight: 0.8000
# - Dependent: https://github.com/ethereum/eth-hash | Weight: 0.2000
# - Dependent: https://github.com/pytest-dev/pytest-xdist | Weight: 0.0000
# - Dependent: https://github.com/pytest-dev/pytest | Weight: 0.0000
# - Dependent: https://github.com/pytest-dev/pytest-cov | Weight: 0.0000
# - Dependent: https://github.com/pycqa/flake8 | Weight: 0.0000
# - Dependent: https://github.com/hypothesisworks/hypothesis | Weight: 0.0000
# - Dependent: https://github.com/ipython/ipython | Weight: 0.0000
# - Dependent: https://github.com/pytest-dev/pytest-asyncio | Weight: 0.0000
# - Dependent: https://github.com/tox-dev/tox | Weight: 0.0000
# - Dependent: https://github.com/python/mypy | Weight: 0.0000
#
# Seed Node: https://github.com/ethereum/web3.py | Weight: 0.2000
# - Dependent: https://github.com/ethereum/eth-abi | Weight: 0.1628
# - Dependent: https://github.com/ethereum/eth-account | Weight: 0.1502
# - Dependent: https://github.com/ethereum/eth-utils | Weight: 0.1491
# - Dependent: https://github.com/ethereum/eth-hash | Weight: 0.1275
# - Dependent: https://github.com/ethereum/eth-typing | Weight: 0.1127
# - Dependent: https://github.com/ethereum/hexbytes | Weight: 0.0977
# - Dependent: https://github.com/aaugustin/websockets | Weight: 0.0000
# - Dependent: https://github.com/aio-libs/aiohttp | Weight: 0.0000
# - Dependent: https://github.com/mlodewijck/pyunormalize | Weight: 0.0000
# - Dependent: https://github.com/python/typing_extensions | Weight: 0.0000
#
# Seed Node: https://github.com/paradigmxyz/reth | Weight: 0.2000
# - Dependent: https://github.com/libp2p/rust-libp2p | Weight: 0.0269
# - Dependent: https://github.com/bluealloy/revm | Weight: 0.0179
# - Dependent: https://github.com/alloy-rs/alloy | Weight: 0.0098
# - Dependent: https://github.com/tokio-rs/tokio | Weight: 0.0098
# - Dependent: https://github.com/rust-lang/cargo | Weight: 0.0097
# - Dependent: https://github.com/alloy-rs/core | Weight: 0.0093
# - Dependent: https://github.com/hyperium/hyper | Weight: 0.0092
# - Dependent: https://github.com/rustwasm/wasm-bindgen | Weight: 0.0087
# - Dependent: https://github.com/clap-rs/clap | Weight: 0.0087
# - Dependent: https://github.com/rust-lang/libc | Weight: 0.0087
#
# Seed Node: https://github.com/consensys/teku | Weight: 0.2000
# - Dependent: https://github.com/lodash/lodash | Weight: 0.0147
# - Dependent: https://github.com/babel/babel | Weight: 0.0144
# - Dependent: https://github.com/eslint/eslint | Weight: 0.0140
# - Dependent: https://github.com/caolan/async | Weight: 0.0130
# - Dependent: https://github.com/jprichardson/node-fs-extra | Weight: 0.0125
# - Dependent: https://github.com/tj/commander.js | Weight: 0.0124
# - Dependent: https://github.com/node-fetch/node-fetch | Weight: 0.0115
# - Dependent: https://github.com/debug-js/debug | Weight: 0.0114
# - Dependent: https://github.com/chalk/chalk | Weight: 0.0113
# - Dependent: https://github.com/acornjs/acorn | Weight: 0.0113
#
# Seed Node: https://github.com/prysmaticlabs/prysm | Weight: 0.2000
# - Dependent: https://github.com/ethereum/go-ethereum | Weight: 0.0664
# - Dependent: https://github.com/libp2p/go-libp2p | Weight: 0.0375
# - Dependent: https://github.com/libp2p/go-libp2p-pubsub | Weight: 0.0344
# - Dependent: https://github.com/libp2p/go-reuseport | Weight: 0.0335
# - Dependent: https://github.com/prysmaticlabs/go-bitfield | Weight: 0.0314
# - Dependent: https://github.com/libp2p/go-yamux | Weight: 0.0309
# - Dependent: https://github.com/prysmaticlabs/fastssz | Weight: 0.0309
# - Dependent: https://github.com/libp2p/go-netroute | Weight: 0.0306
# - Dependent: https://github.com/libp2p/go-mplex | Weight: 0.0306
# - Dependent: https://github.com/libp2p/go-buffer-pool | Weight: 0.0302
#
# Seed Node: https://github.com/erigontech/erigon | Weight: 0.2000
# - Dependent: https://github.com/libp2p/go-libp2p | Weight: 0.0428
# - Dependent: https://github.com/libp2p/go-libp2p-pubsub | Weight: 0.0393
# - Dependent: https://github.com/libp2p/go-reuseport | Weight: 0.0382
# - Dependent: https://github.com/prysmaticlabs/go-bitfield | Weight: 0.0358
# - Dependent: https://github.com/libp2p/go-yamux | Weight: 0.0352
# - Dependent: https://github.com/libp2p/go-mplex | Weight: 0.0350
# - Dependent: https://github.com/libp2p/go-netroute | Weight: 0.0350
# - Dependent: https://github.com/libp2p/go-buffer-pool | Weight: 0.0344
# - Dependent: https://github.com/libp2p/go-nat | Weight: 0.0342
# - Dependent: https://github.com/libp2p/go-msgio | Weight: 0.0339
#
# Seed Node: https://github.com/web3/web3.js | Weight: 0.2000
# - Dependent: https://github.com/ethers-io/ethers.js | Weight: 0.0459
# - Dependent: https://github.com/wevm/viem | Weight: 0.0216
# - Dependent: https://github.com/wevm/abitype | Weight: 0.0183
# - Dependent: https://github.com/wevm/isows | Weight: 0.0158
# - Dependent: https://github.com/definitelytyped/definitelytyped | Weight: 0.0116
# - Dependent: https://github.com/microsoft/typescript | Weight: 0.0106
# - Dependent: https://github.com/remix-run/react-router | Weight: 0.0104
# - Dependent: https://github.com/facebook/docusaurus | Weight: 0.0102
# - Dependent: https://github.com/jestjs/jest | Weight: 0.0099
# - Dependent: https://github.com/babel/babel | Weight: 0.0097
#
# Seed Node: https://github.com/grandinetech/grandine | Weight: 0.2000
# - Dependent: https://github.com/libp2p/rust-libp2p | Weight: 0.0286
# - Dependent: https://github.com/tokio-rs/tokio | Weight: 0.0104
# - Dependent: https://github.com/rust-lang/cargo | Weight: 0.0103
# - Dependent: https://github.com/hyperium/hyper | Weight: 0.0098
# - Dependent: https://github.com/rustwasm/wasm-bindgen | Weight: 0.0092
# - Dependent: https://github.com/tokio-rs/axum | Weight: 0.0092
# - Dependent: https://github.com/clap-rs/clap | Weight: 0.0092
# - Dependent: https://github.com/rust-lang/libc | Weight: 0.0092
# - Dependent: https://github.com/serde-rs/serde | Weight: 0.0088
# - Dependent: https://github.com/sfackler/rust-openssl | Weight: 0.0088
#
# Seed Node: https://github.com/chainsafe/lodestar | Weight: 0.2000
# - Dependent: https://github.com/ethers-io/ethers.js | Weight: 0.0490
# - Dependent: https://github.com/libp2p/js-libp2p | Weight: 0.0249
# - Dependent: https://github.com/chainsafe/lodestar | Weight: 0.0197
# - Dependent: https://github.com/vuejs/vue | Weight: 0.0125
# - Dependent: https://github.com/definitelytyped/definitelytyped | Weight: 0.0124
# - Dependent: https://github.com/ipfs/protons | Weight: 0.0120
# - Dependent: https://github.com/ipfs/js-datastore-level | Weight: 0.0115
# - Dependent: https://github.com/ipfs/js-stores | Weight: 0.0115
# - Dependent: https://github.com/microsoft/typescript | Weight: 0.0113
# - Dependent: https://github.com/remix-run/react-router | Weight: 0.0111
#
# Seed Node: https://github.com/sigp/lighthouse | Weight: 0.2000
# - Dependent: https://github.com/libp2p/rust-libp2p | Weight: 0.0266
# - Dependent: https://github.com/alloy-rs/alloy | Weight: 0.0097
# - Dependent: https://github.com/tokio-rs/tokio | Weight: 0.0096
# - Dependent: https://github.com/rust-lang/cargo | Weight: 0.0096
# - Dependent: https://github.com/alloy-rs/core | Weight: 0.0092
# - Dependent: https://github.com/hyperium/hyper | Weight: 0.0091
# - Dependent: https://github.com/diesel-rs/diesel | Weight: 0.0086
# - Dependent: https://github.com/rustwasm/wasm-bindgen | Weight: 0.0086
# - Dependent: https://github.com/tokio-rs/axum | Weight: 0.0086
# - Dependent: https://github.com/clap-rs/clap | Weight: 0.0086
#
# Seed Node: https://github.com/ethereum/go-ethereum | Weight: 0.2000
# - Dependent: https://github.com/prometheus/client_golang | Weight: 0.0574
# - Dependent: https://github.com/azure/azure-sdk-for-go | Weight: 0.0547
# - Dependent: https://github.com/aws/aws-sdk-go-v2 | Weight: 0.0525
# - Dependent: https://github.com/google/pprof | Weight: 0.0520
# - Dependent: https://github.com/google/uuid | Weight: 0.0480
# - Dependent: https://github.com/prometheus/common | Weight: 0.0468
# - Dependent: https://github.com/prometheus/procfs | Weight: 0.0468
# - Dependent: https://github.com/deckarep/golang-set | Weight: 0.0456
# - Dependent: https://github.com/hashicorp/go-retryablehttp | Weight: 0.0450
# - Dependent: https://github.com/getsentry/sentry-go | Weight: 0.0435
#
# Seed Node: https://github.com/status-im/nimbus-eth2 | Weight: 0.2000
# - Dependent: https://github.com/numpy/numpy | Weight: 0.2000
# - Dependent: https://github.com/pandas-dev/pandas | Weight: 0.2000
# - Dependent: https://github.com/prometheus/client_python | Weight: 0.1558
# - Dependent: https://github.com/mozilla/bleach | Weight: 0.1287
# - Dependent: https://github.com/microsoft/debugpy | Weight: 0.1155
# - Dependent: https://github.com/python-markdown/markdown | Weight: 0.0000
# - Dependent: https://github.com/pypa/wheel | Weight: 0.0000
# - Dependent: https://github.com/3-manifolds/plink | Weight: 0.0000
# - Dependent: https://github.com/matplotlib/cycler | Weight: 0.0000
# - Dependent: https://github.com/pexpect/ptyprocess | Weight: 0.0000
#
# Seed Node: https://github.com/ethereum/remix-project | Weight: 0.2000
# - Dependent: https://github.com/ethers-io/ethers.js | Weight: 0.0365
# - Dependent: https://github.com/walletconnect/walletconnect-monorepo | Weight: 0.0160
# - Dependent: https://github.com/ethereum/remix-project | Weight: 0.0148
# - Dependent: https://github.com/wevm/abitype | Weight: 0.0145
# - Dependent: https://github.com/openzeppelin/openzeppelin-upgrades | Weight: 0.0144
# - Dependent: https://github.com/walletconnect/walletconnect-utils | Weight: 0.0141
# - Dependent: https://github.com/openzeppelin/contracts-wizard | Weight: 0.0138
# - Dependent: https://github.com/ethereum/remix-plugin | Weight: 0.0128
# - Dependent: https://github.com/walletconnect/modal | Weight: 0.0127
# - Dependent: https://github.com/definitelytyped/definitelytyped | Weight: 0.0092
#
# Seed Node: https://github.com/safe-global/safe-smart-account | Weight: 0.2000
# - Dependent: https://github.com/ethers-io/ethers.js | Weight: 0.0855
# - Dependent: https://github.com/nomicfoundation/hardhat | Weight: 0.0633
# - Dependent: https://github.com/wighawag/hardhat-deploy | Weight: 0.0289
# - Dependent: https://github.com/definitelytyped/definitelytyped | Weight: 0.0216
# - Dependent: https://github.com/microsoft/typescript | Weight: 0.0198
# - Dependent: https://github.com/babel/babel | Weight: 0.0181
# - Dependent: https://github.com/ethereumjs/ethereumjs-monorepo | Weight: 0.0177
# - Dependent: https://github.com/typescript-eslint/typescript-eslint | Weight: 0.0166
# - Dependent: https://github.com/immutable-js/immutable-js | Weight: 0.0157
# - Dependent: https://github.com/getsentry/sentry-javascript | Weight: 0.0154
#
# Seed Node: https://github.com/eth-infinitism/account-abstraction | Weight: 0.2000
# - Dependent: https://github.com/ethers-io/ethers.js | Weight: 0.0153
# - Dependent: https://github.com/nomicfoundation/hardhat | Weight: 0.0113
# - Dependent: https://github.com/openzeppelin/openzeppelin-contracts | Weight: 0.0074
# - Dependent: https://github.com/wighawag/hardhat-deploy | Weight: 0.0052
# - Dependent: https://github.com/definitelytyped/definitelytyped | Weight: 0.0039
# - Dependent: https://github.com/expressjs/express | Weight: 0.0036
# - Dependent: https://github.com/microsoft/typescript | Weight: 0.0035
# - Dependent: https://github.com/axios/axios | Weight: 0.0035
# - Dependent: https://github.com/lodash/lodash | Weight: 0.0033
# - Dependent: https://github.com/babel/babel | Weight: 0.0032
#
# Seed Node: https://github.com/ethereumjs/ethereumjs-monorepo | Weight: 0.2000
# - Dependent: https://github.com/ethers-io/ethers.js | Weight: 0.0771
# - Dependent: https://github.com/definitelytyped/definitelytyped | Weight: 0.0195
# - Dependent: https://github.com/microsoft/typescript | Weight: 0.0178
# - Dependent: https://github.com/puppeteer/puppeteer | Weight: 0.0172
# - Dependent: https://github.com/babel/babel | Weight: 0.0163
# - Dependent: https://github.com/ethereumjs/ethereumjs-monorepo | Weight: 0.0160
# - Dependent: https://github.com/reactivex/rxjs | Weight: 0.0151
# - Dependent: https://github.com/typescript-eslint/typescript-eslint | Weight: 0.0150
# - Dependent: https://github.com/webdriverio/webdriverio | Weight: 0.0148
# - Dependent: https://github.com/postcss/postcss | Weight: 0.0139

# %% [markdown]
# # Export the graph to JSON

# %%
print("\nLevel 1 Nodes (Sources) and Their Summed Edge Weights:")
source_weights = validate_weights(G)
pd.Series(source_weights)
# Out:
# Level 1 Nodes (Sources) and Their Summed Edge Weights:
# https://github.com/ethereum/solidity                     0.0
# https://github.com/vyperlang/vyper                       0.0
# https://github.com/ethereum/py-evm                       0.2
# https://github.com/ethereum/web3.py                      0.8
# https://github.com/paradigmxyz/reth                      0.8
# https://github.com/consensys/teku                        0.8
# https://github.com/prysmaticlabs/prysm                   0.8
# https://github.com/erigontech/erigon                     0.8
# https://github.com/web3/web3.js                          0.8
# https://github.com/grandinetech/grandine                 0.8
# https://github.com/chainsafe/lodestar                    0.8
# https://github.com/sigp/lighthouse                       0.8
# https://github.com/ethereum/go-ethereum                  0.8
# https://github.com/status-im/nimbus-eth2                 0.8
# https://github.com/ethereum/remix-project                0.8
# https://github.com/safe-global/safe-smart-account        0.8
# https://github.com/eth-infinitism/account-abstraction    0.8
# https://github.com/ethereumjs/ethereumjs-monorepo        0.8
# dtype: float64

# %%
G_serializable = convert_graph_to_serializable(G)
graph_json = nx.node_link_data(G_serializable)
output_path = "../../graph/weighting_examples/oso_forks_and_funding_weighted_graph.json"
with open(output_path, "w") as f:
    json.dump(graph_json, f, indent=2)
