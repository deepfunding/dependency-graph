# %%
from collections import defaultdict
from itertools import combinations
import json
import networkx as nx
import numpy as np
import os
import pandas as pd

# %% [markdown]
# # Load the unweighted graph

# %%
with open('../../graph/unweighted_graph.json', 'r') as f:
    graph_data = json.load(f)

G = nx.node_link_graph(graph_data)
print("Nodes:", len(G.nodes))
repo_urls = [x for x in G.nodes]
print("Edges:", len(G.edges))
# Out:
# Nodes: 4303
# Edges: 9896

# %% [markdown]
# # Grab OSS funding event data for all relevant repos
#
# - Subscribe to the OSO Production dataset on BigQuery (see docs [here](https://docs.opensource.observer/docs/get-started/bigquery))
# - Run the query below and export it to a CSV file

# %%
from google.cloud import bigquery

# replace with your path to credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../oso_gcp_credentials.json'

# replace with your project name
client = bigquery.Client(project='opensource-observer')

# %%
def stringify_array(arr):
    return "'" + "','".join(arr) + "'"

query = f"""
WITH funding AS (
    SELECT
        date_trunc(time, QUARTER) AS quarter,        
        from_project_name,
        grant_pool_name,
        to_project_name,
        to_project_id,
        CAST(sum(amount) AS INT) AS total_funding_usd
    FROM `oso_production.oss_funding_v0`
    GROUP BY 1, 2, 3, 4, 5
),
repos as (
    SELECT
        project_id,
        MAX_BY(artifact_url, star_count) AS git_repo_with_most_stars
    FROM `oso_production.repositories_v0`
    WHERE artifact_url IN ({stringify_array(repo_urls)})
    GROUP BY project_id    
)
SELECT
    funding.* EXCEPT (to_project_id),
    repos.git_repo_with_most_stars
FROM funding
JOIN repos
    ON funding.to_project_id = repos.project_id
"""

# results = client.query(query)
# df = results.to_dataframe()
# df.to_parquet('../../datasets/oso/oss_funding.parquet')

df = pd.read_parquet('../../datasets/oso/oss_funding.parquet')
df.tail(5)
# Out:
#                        quarter from_project_name grant_pool_name  \
# 1424 2020-04-01 00:00:00+00:00    opencollective   contributions
# 1425 2019-10-01 00:00:00+00:00    opencollective   contributions
# 1426 2024-01-01 00:00:00+00:00          optimism       retropgf3
# 1427 2018-07-01 00:00:00+00:00    opencollective   contributions
# 1428 2024-01-01 00:00:00+00:00          optimism       retropgf3
#
#       to_project_name  total_funding_usd            git_repo_with_most_stars
# 1424          dcodeio              15000  https://github.com/dcodeio/long.js
# 1425         motdotla                258  https://github.com/motdotla/dotenv
# 1426  lighthouse-sigp            1043482  https://github.com/sigp/lighthouse
# 1427        gregberge                233   https://github.com/gregberge/svgr
# 1428             web3             869569     https://github.com/web3/web3.js

# %%
query = f"""
SELECT
    artifact_url,
    star_count,
    fork_count,
    language
FROM `oso_production.repositories_v0`
WHERE artifact_url IN ({stringify_array(repo_urls)})
ORDER BY star_count DESC
"""

# results = client.query(query)
# df_repos = results.to_dataframe()
# df_repos.to_csv('../../datasets/oso/repo_basic_stats.csv')

df_repos = pd.read_csv('../../datasets/oso/repo_basic_stats.csv', index_col=0).set_index('artifact_url')
df_repos.tail(5)
# Out:
#                                                     star_count  fork_count  \
# artifact_url
# https://github.com/es-shims/arraybuffer.prototy...           0           0
# https://github.com/inspect-js/typed-array-byte-...           0           0
# https://github.com/syntax-tree/unist-util-posit...           0           0
# https://github.com/silentcicero/is-hex-prefixed              0           1
# https://github.com/prysmaticlabs/prombbolt                   0           0
#
#                                                       language
# artifact_url
# https://github.com/es-shims/arraybuffer.prototy...  JavaScript
# https://github.com/inspect-js/typed-array-byte-...  JavaScript
# https://github.com/syntax-tree/unist-util-posit...  JavaScript
# https://github.com/silentcicero/is-hex-prefixed     JavaScript
# https://github.com/prysmaticlabs/prombbolt            Starlark

# %% [markdown]
# # Simulate Pairwise comparisons and create an ELO rating
#
# - First, we organize funding decisions into quarterly groups and compares projects within the same round and quarter based on their relative funding amounts. This allows for a direct comparison of projects that were evaluated at the same time.
# - Next, we use a basic ELO model and assign a rating for each project
# - Finally, we run the analysis for web2 and web3 projects separately

# %%
def pairwise_simulation(dataframe):

    data = []
    
    funding_rounds = dataframe.groupby(['from_project_name', 'quarter'])['to_project_name'].nunique()
    funding_rounds = funding_rounds[funding_rounds > 1]
    
    for funder, quarter in funding_rounds.keys():
        dff = dataframe[(dataframe['from_project_name'] == funder) & (dataframe['quarter'] == quarter)]
        projects = list(dff['to_project_name'].unique())
        comparisons = combinations(projects, 2)
        for (project_a,project_b) in comparisons:
            amount_a = dff[dff['to_project_name'] == project_a]['total_funding_usd'].sum()
            amount_b = dff[dff['to_project_name'] == project_b]['total_funding_usd'].sum()
            repo_a = dff[dff['to_project_name'] == project_a]['git_repo_with_most_stars'].unique()[0]
            repo_b = dff[dff['to_project_name'] == project_b]['git_repo_with_most_stars'].unique()[0]
            amount_total = amount_a + amount_b
            data.append({
                'funder': funder,
                'quarter': quarter,
                'project_a': repo_a,
                'project_b': repo_b,
                'weight_a': amount_a / amount_total,
                'weight_b': amount_b / amount_total
            })

    return pd.DataFrame(data)

df_pairwise = pairwise_simulation(df)
df_pairwise.tail()
# Out:
#          funder                   quarter  \
# 20646  optimism 2024-10-01 00:00:00+00:00
# 20647  optimism 2024-10-01 00:00:00+00:00
# 20648  optimism 2024-10-01 00:00:00+00:00
# 20649  optimism 2024-10-01 00:00:00+00:00
# 20650  optimism 2024-10-01 00:00:00+00:00
#
#                                                project_a  \
# 20646                  https://github.com/bluealloy/revm
# 20647                  https://github.com/bluealloy/revm
# 20648           https://github.com/status-im/nimbus-eth2
# 20649           https://github.com/status-im/nimbus-eth2
# 20650  https://github.com/ethereumjs/ethereumjs-monorepo
#
#                                                project_b  weight_a  weight_b
# 20646  https://github.com/ethereumjs/ethereumjs-monorepo  0.514987  0.485013
# 20647  https://github.com/eth-infinitism/account-abst...  0.447073  0.552927
# 20648  https://github.com/ethereumjs/ethereumjs-monorepo  0.460606  0.539394
# 20649  https://github.com/eth-infinitism/account-abst...  0.394038  0.605962
# 20650  https://github.com/eth-infinitism/account-abst...  0.432302  0.567698

# %%
def expected_score(rating_a, rating_b):
    return 1 / (1 + 10 ** ((rating_b - rating_a) / 400))

def update_elo(rating_a, rating_b, score_a, k_factor):
    expected_a = expected_score(rating_a, rating_b)
    rating_a_new = rating_a + k_factor * (score_a - expected_a)
    rating_b_new = rating_b + k_factor * ((1 - score_a) - (1 - expected_a))
    return rating_a_new, rating_b_new
    
def elo_simulation(dataframe):
    
    elo_ratings = defaultdict(lambda: 1500) # Default ELO rating for all projects
    appearances = defaultdict(int)
    
    for _,row in dataframe.iterrows():
        project_a = row['project_a']
        project_b = row['project_b']
        share_a = row['weight_a']
        score_a = 1 if share_a > 0.5 else 0 if share_a < 0.5 else 0.5

        k_a = 40 / (1 + appearances[project_a] / 5)
        k_b = 40 / (1 + appearances[project_b] / 5)
        k_factor = (k_a + k_b) / 2
        
        elo_ratings[project_a], elo_ratings[project_b] = update_elo(
            elo_ratings[project_a], elo_ratings[project_b], score_a, k_factor
        )
        appearances[project_a] += 1
        appearances[project_b] += 1
    
    margin_of_error = {project: 400 / np.sqrt(appearances[project]) for project in appearances}

    return (
        pd.DataFrame([
            {
                'project': project,
                'head-to-head_comparisons': appearances[project],        
                'elo_rating': rating,        
                'margin_of_error': margin_of_error[project]
            }
            for project, rating in elo_ratings.items()
        ])
        .sort_values(by='elo_rating', ascending=False)
        .set_index('project', drop=True)
    )

# %%
web3 = elo_simulation(df_pairwise[df_pairwise['funder'] != 'opencollective'])
web3_projects = list(web3.index)
web3
# Out:
#                                                     head-to-head_comparisons  \
# project
# https://github.com/ethers-io/ethers.js                                   197
# https://github.com/prysmaticlabs/prysm                                   118
# https://github.com/sigp/lighthouse                                       207
# https://github.com/libp2p/go-libp2p                                       36
# https://github.com/ethereum/solidity                                      80
# https://github.com/wevm/viem                                             119
# https://github.com/ethereum/go-ethereum                                  119
# https://github.com/web3/web3.js                                           33
# https://github.com/erigontech/erigon                                      14
# https://github.com/nomicfoundation/hardhat                               153
# https://github.com/openzeppelin/openzeppelin-co...                        87
# https://github.com/paradigmxyz/reth                                       36
# https://github.com/safe-global/safe-smart-account                         17
# https://github.com/eth-infinitism/account-abstr...                        53
# https://github.com/grandinetech/grandine                                  14
# https://github.com/vyperlang/vyper                                       173
# https://github.com/walletconnect/walletconnect-...                        98
# https://github.com/ethereum/remix-project                                 66
# https://github.com/ethereum/web3.py                                        1
# https://github.com/ethereumjs/ethereumjs-monorepo                         14
# https://github.com/chainsafe/lodestar                                    125
# https://github.com/status-im/nimbus-eth2                                  53
# https://github.com/bluealloy/revm                                         60
# https://github.com/ethereum/solc-js                                       14
# https://github.com/ipfs/js-ipfs                                           32
# https://github.com/wighawag/hardhat-deploy                               161
# https://github.com/alloy-rs/core                                          22
# https://github.com/supranational/blst                                     39
# https://github.com/quic-go/quic-go                                        14
# https://github.com/prettier-solidity/prettier-p...                       122
# https://github.com/consensys/teku                                         90
# https://github.com/protofire/solhint                                      44
# https://github.com/crate-crypto/go-ipa                                    39
#
#                                                      elo_rating  \
# project
# https://github.com/ethers-io/ethers.js              1702.260766
# https://github.com/prysmaticlabs/prysm              1676.748565
# https://github.com/sigp/lighthouse                  1675.604412
# https://github.com/libp2p/go-libp2p                 1609.248967
# https://github.com/ethereum/solidity                1592.043199
# https://github.com/wevm/viem                        1587.453234
# https://github.com/ethereum/go-ethereum             1579.410411
# https://github.com/web3/web3.js                     1556.478705
# https://github.com/erigontech/erigon                1528.076996
# https://github.com/nomicfoundation/hardhat          1526.576219
# https://github.com/openzeppelin/openzeppelin-co...  1520.912036
# https://github.com/paradigmxyz/reth                 1513.434153
# https://github.com/safe-global/safe-smart-account   1507.439104
# https://github.com/eth-infinitism/account-abstr...  1502.959254
# https://github.com/grandinetech/grandine            1502.880988
# https://github.com/vyperlang/vyper                  1501.608560
# https://github.com/walletconnect/walletconnect-...  1498.120961
# https://github.com/ethereum/remix-project           1494.729175
# https://github.com/ethereum/web3.py                 1488.097611
# https://github.com/ethereumjs/ethereumjs-monorepo   1484.308236
# https://github.com/chainsafe/lodestar               1470.769423
# https://github.com/status-im/nimbus-eth2            1470.169571
# https://github.com/bluealloy/revm                   1442.361238
# https://github.com/ethereum/solc-js                 1441.461295
# https://github.com/ipfs/js-ipfs                     1439.130733
# https://github.com/wighawag/hardhat-deploy          1427.969694
# https://github.com/alloy-rs/core                    1417.219380
# https://github.com/supranational/blst               1402.308329
# https://github.com/quic-go/quic-go                  1399.877797
# https://github.com/prettier-solidity/prettier-p...  1395.937501
# https://github.com/consensys/teku                   1392.078916
# https://github.com/protofire/solhint                1389.041129
# https://github.com/crate-crypto/go-ipa              1363.283442
#
#                                                     margin_of_error
# project
# https://github.com/ethers-io/ethers.js                    28.498820
# https://github.com/prysmaticlabs/prysm                    36.822985
# https://github.com/sigp/lighthouse                        27.801922
# https://github.com/libp2p/go-libp2p                       66.666667
# https://github.com/ethereum/solidity                      44.721360
# https://github.com/wevm/viem                              36.667940
# https://github.com/ethereum/go-ethereum                   36.667940
# https://github.com/web3/web3.js                           69.631062
# https://github.com/erigontech/erigon                     106.904497
# https://github.com/nomicfoundation/hardhat                32.338083
# https://github.com/openzeppelin/openzeppelin-co...        42.884501
# https://github.com/paradigmxyz/reth                       66.666667
# https://github.com/safe-global/safe-smart-account         97.014250
# https://github.com/eth-infinitism/account-abstr...        54.944226
# https://github.com/grandinetech/grandine                 106.904497
# https://github.com/vyperlang/vyper                        30.411437
# https://github.com/walletconnect/walletconnect-...        40.406102
# https://github.com/ethereum/remix-project                 49.236596
# https://github.com/ethereum/web3.py                      400.000000
# https://github.com/ethereumjs/ethereumjs-monorepo        106.904497
# https://github.com/chainsafe/lodestar                     35.777088
# https://github.com/status-im/nimbus-eth2                  54.944226
# https://github.com/bluealloy/revm                         51.639778
# https://github.com/ethereum/solc-js                      106.904497
# https://github.com/ipfs/js-ipfs                           70.710678
# https://github.com/wighawag/hardhat-deploy                31.524416
# https://github.com/alloy-rs/core                          85.280287
# https://github.com/supranational/blst                     64.051262
# https://github.com/quic-go/quic-go                       106.904497
# https://github.com/prettier-solidity/prettier-p...        36.214298
# https://github.com/consensys/teku                         42.163702
# https://github.com/protofire/solhint                      60.302269
# https://github.com/crate-crypto/go-ipa                    64.051262

# %%
web2 = elo_simulation(
    df_pairwise[(~df_pairwise['project_a'].isin(web3_projects)) & (~df_pairwise['project_b'].isin(web3_projects))]
)
web2.head(40)
# Out:
#                                                     head-to-head_comparisons  \
# project
# https://github.com/webpack/webpack                                       974
# https://github.com/babel/babel                                           969
# https://github.com/eslint/eslint                                         899
# https://github.com/vuejs/vue                                             964
# https://github.com/mochajs/mocha                                         976
# https://github.com/salesforce/tough-cookie                               401
# https://github.com/dcodeio/long.js                                       366
# https://github.com/zloirock/core-js                                      899
# https://github.com/tokio-rs/tokio                                        667
# https://github.com/mafintosh/pump                                        150
# https://github.com/prettier/prettier                                     880
# https://github.com/pandas-dev/pandas                                     419
# https://github.com/getsentry/sentry-javascript                            95
# https://github.com/sindresorhus/type-fest                                899
# https://github.com/numpy/numpy                                           546
# https://github.com/yahoo/serialize-javascript                             52
# https://github.com/gulpjs/gulp                                           976
# https://github.com/coinbase/coinbase-wallet-sdk                           61
# https://github.com/rollup/rollup                                         950
# https://github.com/electron/electron                                     939
# https://github.com/mysticatea/abort-controller                            42
# https://github.com/wooorm/markdown-table                                 143
# https://github.com/pnpm/cmd-shim                                         913
# https://github.com/fb55/entities                                          32
# https://github.com/typescript-eslint/typescript...                       856
# https://github.com/epoberezkin/fast-deep-equal                           173
# https://github.com/yarnpkg/yarn                                          699
# https://github.com/redux-saga/redux-saga                                 972
# https://github.com/ajv-validator/ajv                                     826
# https://github.com/emotion-js/emotion                                    926
# https://github.com/marak/colors.js                                       171
# https://github.com/swc-project/swc                                       899
# https://github.com/floating-ui/floating-ui                               794
# https://github.com/qix-/color-convert                                     70
# https://github.com/servo/rust-smallvec                                   138
# https://github.com/xtuc/webassemblyjs                                     94
# https://github.com/postcss/postcss                                       826
# https://github.com/biomejs/biome                                         230
# https://github.com/vercel/swr                                            588
# https://github.com/lukeed/polka                                          200
#
#                                                      elo_rating  \
# project
# https://github.com/webpack/webpack                  1859.270668
# https://github.com/babel/babel                      1831.594509
# https://github.com/eslint/eslint                    1794.178747
# https://github.com/vuejs/vue                        1771.325874
# https://github.com/mochajs/mocha                    1672.830486
# https://github.com/salesforce/tough-cookie          1671.403054
# https://github.com/dcodeio/long.js                  1664.616819
# https://github.com/zloirock/core-js                 1663.900092
# https://github.com/tokio-rs/tokio                   1659.227687
# https://github.com/mafintosh/pump                   1657.895970
# https://github.com/prettier/prettier                1652.261456
# https://github.com/pandas-dev/pandas                1629.576754
# https://github.com/getsentry/sentry-javascript      1628.362000
# https://github.com/sindresorhus/type-fest           1627.295238
# https://github.com/numpy/numpy                      1620.370116
# https://github.com/yahoo/serialize-javascript       1616.965454
# https://github.com/gulpjs/gulp                      1600.853121
# https://github.com/coinbase/coinbase-wallet-sdk     1593.533677
# https://github.com/rollup/rollup                    1578.316260
# https://github.com/electron/electron                1574.090689
# https://github.com/mysticatea/abort-controller      1572.394419
# https://github.com/wooorm/markdown-table            1571.603493
# https://github.com/pnpm/cmd-shim                    1564.397322
# https://github.com/fb55/entities                    1562.650734
# https://github.com/typescript-eslint/typescript...  1557.780771
# https://github.com/epoberezkin/fast-deep-equal      1548.630024
# https://github.com/yarnpkg/yarn                     1541.210938
# https://github.com/redux-saga/redux-saga            1537.526309
# https://github.com/ajv-validator/ajv                1531.131551
# https://github.com/emotion-js/emotion               1526.581537
# https://github.com/marak/colors.js                  1524.861046
# https://github.com/swc-project/swc                  1510.956147
# https://github.com/floating-ui/floating-ui          1506.116964
# https://github.com/qix-/color-convert               1500.807574
# https://github.com/servo/rust-smallvec              1499.491133
# https://github.com/xtuc/webassemblyjs               1497.090332
# https://github.com/postcss/postcss                  1495.231463
# https://github.com/biomejs/biome                    1494.075150
# https://github.com/vercel/swr                       1486.793024
# https://github.com/lukeed/polka                     1482.603685
#
#                                                     margin_of_error
# project
# https://github.com/webpack/webpack                        12.816827
# https://github.com/babel/babel                            12.849851
# https://github.com/eslint/eslint                          13.340747
# https://github.com/vuejs/vue                              12.883133
# https://github.com/mochajs/mocha                          12.803688
# https://github.com/salesforce/tough-cookie                19.975047
# https://github.com/dcodeio/long.js                        20.908335
# https://github.com/zloirock/core-js                       13.340747
# https://github.com/tokio-rs/tokio                         15.488062
# https://github.com/mafintosh/pump                         32.659863
# https://github.com/prettier/prettier                      13.483997
# https://github.com/pandas-dev/pandas                      19.541279
# https://github.com/getsentry/sentry-javascript            41.039134
# https://github.com/sindresorhus/type-fest                 13.340747
# https://github.com/numpy/numpy                            17.118420
# https://github.com/yahoo/serialize-javascript             55.470020
# https://github.com/gulpjs/gulp                            12.803688
# https://github.com/coinbase/coinbase-wallet-sdk           51.214752
# https://github.com/rollup/rollup                          12.977714
# https://github.com/electron/electron                      13.053507
# https://github.com/mysticatea/abort-controller            61.721340
# https://github.com/wooorm/markdown-table                  33.449680
# https://github.com/pnpm/cmd-shim                          13.238068
# https://github.com/fb55/entities                          70.710678
# https://github.com/typescript-eslint/typescript...        13.671719
# https://github.com/epoberezkin/fast-deep-equal            30.411437
# https://github.com/yarnpkg/yarn                           15.129389
# https://github.com/redux-saga/redux-saga                  12.830006
# https://github.com/ajv-validator/ajv                      13.917780
# https://github.com/emotion-js/emotion                     13.144816
# https://github.com/marak/colors.js                        30.588765
# https://github.com/swc-project/swc                        13.340747
# https://github.com/floating-ui/floating-ui                14.195469
# https://github.com/qix-/color-convert                     47.809144
# https://github.com/servo/rust-smallvec                    34.050261
# https://github.com/xtuc/webassemblyjs                     41.256850
# https://github.com/postcss/postcss                        13.917780
# https://github.com/biomejs/biome                          26.375219
# https://github.com/vercel/swr                             16.495722
# https://github.com/lukeed/polka                           28.284271

# %% [markdown]
# # Use funding data to help prune the tree

# %%
all_elo = pd.concat([web2, web3])
all_elo = all_elo.join(df_repos)[['language']]
df_repos_filtered = df_repos.loc[~df_repos.index.isin(all_elo.index)][['language']]
repo_rank = pd.concat([all_elo, df_repos_filtered]).reset_index()
repo_rank['owner'] = repo_rank['index'].apply(lambda x: x.split('/')[-2])
repo_rank = repo_rank.drop_duplicates(subset=['owner'], keep='first').set_index('index')

# %%
MAX_DEP_COUNT = 20

g_pruned = []
node_levels = {}

for seed_node, node_data in G.nodes(data=True):
    if node_data.get('level') == 1:
        node_levels[seed_node] = 1        
        all_dependencies = set(G.successors(seed_node))
        if len(all_dependencies) < MAX_DEP_COUNT:
            top_dependencies = all_dependencies
        else:
            top_dependencies = [x for x in all_dependencies if x in repo_rank.index]
            if len(top_dependencies) > MAX_DEP_COUNT:
                top_dependencies = top_dependencies[:MAX_DEP_COUNT]
        
        for dep_node in top_dependencies:
            node_levels[dep_node] = 2            
            g_pruned.append((seed_node, dep_node))

last_node = seed_node
G_pruned = nx.from_edgelist(g_pruned)
nx.set_node_attributes(G_pruned, node_levels, 'level')

print("Kept", len(G_pruned.nodes()), "nodes out of", len(G.nodes()))
print("Kept", len(G_pruned.edges()), "edges out of", len(G.edges()))
# Out:
# Kept 160 nodes out of 4303
# Kept 269 edges out of 9896

# %%
print("- ethereum/")
for seed_node, node_data in G_pruned.nodes(data=True):
    if node_data.get('level') != 1:
        continue
    print("    ├")        
    print("    ├──", seed_node)
    for i, leaf_node in enumerate(sorted(G_pruned.neighbors(seed_node))):
        if seed_node != last_node:
            print("    │   ├── ", f"[{i+1}]", leaf_node)
        else:
            print("        ├── ", f"[{i+1}]", leaf_node)
# Out:
# - ethereum/
#     ├
#     ├── https://github.com/ethereum/solidity
#     │   ├──  [1] https://github.com/readthedocs/sphinx_rtd_theme
#     │   ├──  [2] https://github.com/sphinx-doc/sphinx
#     │   ├──  [3] https://github.com/taminomara/sphinx-a4doc
#     ├
#     ├── https://github.com/vyperlang/vyper
#     │   ├──  [1] https://github.com/agronholm/cbor2
#     │   ├──  [2] https://github.com/executablebooks/sphinx-copybutton
#     │   ├──  [3] https://github.com/gristlabs/asttokens
#     │   ├──  [4] https://github.com/legrandin/pycryptodome
#     │   ├──  [5] https://github.com/lepture/shibuya
#     │   ├──  [6] https://github.com/pypa/packaging
#     │   ├──  [7] https://github.com/pypa/wheel
#     │   ├──  [8] https://github.com/python/importlib_metadata
#     │   ├──  [9] https://github.com/sphinx-doc/sphinx
#     ├
#     ├── https://github.com/ethereum/py-evm
#     │   ├──  [1] https://github.com/ethereum/eth-hash
#     │   ├──  [2] https://github.com/hypothesisworks/hypothesis
#     │   ├──  [3] https://github.com/ipython/ipython
#     │   ├──  [4] https://github.com/peritus/bumpversion
#     │   ├──  [5] https://github.com/pycqa/flake8
#     │   ├──  [6] https://github.com/pytest-dev/pytest
#     │   ├──  [7] https://github.com/pytest-dev/pytest-asyncio
#     │   ├──  [8] https://github.com/pytest-dev/pytest-cov
#     │   ├──  [9] https://github.com/pytest-dev/pytest-xdist
#     │   ├──  [10] https://github.com/python/mypy
#     │   ├──  [11] https://github.com/tox-dev/tox
#     ├
#     ├── https://github.com/ethereum/web3.py
#     │   ├──  [1] https://github.com/aaugustin/websockets
#     │   ├──  [2] https://github.com/aio-libs/aiohttp
#     │   ├──  [3] https://github.com/ethereum/eth-abi
#     │   ├──  [4] https://github.com/ethereum/eth-account
#     │   ├──  [5] https://github.com/ethereum/eth-hash
#     │   ├──  [6] https://github.com/ethereum/eth-typing
#     │   ├──  [7] https://github.com/ethereum/eth-utils
#     │   ├──  [8] https://github.com/ethereum/hexbytes
#     │   ├──  [9] https://github.com/mlodewijck/pyunormalize
#     │   ├──  [10] https://github.com/psf/requests
#     │   ├──  [11] https://github.com/pydantic/pydantic
#     │   ├──  [12] https://github.com/python/typeshed
#     │   ├──  [13] https://github.com/python/typing_extensions
#     ├
#     ├── https://github.com/paradigmxyz/reth
#     │   ├──  [1] https://github.com/amanieu/parking_lot
#     │   ├──  [2] https://github.com/aurora-is-near/aurora-engine
#     │   ├──  [3] https://github.com/bheisler/criterion.rs
#     │   ├──  [4] https://github.com/enarx/ciborium
#     │   ├──  [5] https://github.com/ferrilab/ferrilab
#     │   ├──  [6] https://github.com/gyscos/zstd-rs
#     │   ├──  [7] https://github.com/hyperium/hyper
#     │   ├──  [8] https://github.com/jeltef/derive_more
#     │   ├──  [9] https://github.com/peternator7/strum
#     │   ├──  [10] https://github.com/quinn-rs/quinn
#     │   ├──  [11] https://github.com/recmo/uint
#     │   ├──  [12] https://github.com/rust-bitcoin/rust-secp256k1
#     │   ├──  [13] https://github.com/rust-fuzz/arbitrary
#     │   ├──  [14] https://github.com/rust-lang/cargo
#     │   ├──  [15] https://github.com/rustwasm/wasm-bindgen
#     │   ├──  [16] https://github.com/servo/rust-smallvec
#     │   ├──  [17] https://github.com/supranational/blst
#     │   ├──  [18] https://github.com/toml-rs/toml
#     │   ├──  [19] https://github.com/tower-rs/tower
#     │   ├──  [20] https://github.com/trailofbits/test-fuzz
#     ├
#     ├── https://github.com/consensys/teku
#     │   ├──  [1] https://github.com/alexei/sprintf.js
#     │   ├──  [2] https://github.com/babel/babel
#     │   ├──  [3] https://github.com/caolan/async
#     │   ├──  [4] https://github.com/chalk/chalk
#     │   ├──  [5] https://github.com/colorjs/color-name
#     │   ├──  [6] https://github.com/eslint/eslint
#     │   ├──  [7] https://github.com/gkz/prelude-ls
#     │   ├──  [8] https://github.com/hiddentao/fast-levenshtein
#     │   ├──  [9] https://github.com/humanwhocodes/object-schema
#     │   ├──  [10] https://github.com/ionicabizau/git-url-parse
#     │   ├──  [11] https://github.com/jprichardson/node-fs-extra
#     │   ├──  [12] https://github.com/kaelzhang/node-ignore
#     │   ├──  [13] https://github.com/lodash/lodash
#     │   ├──  [14] https://github.com/lydell/js-tokens
#     │   ├──  [15] https://github.com/mattiasbuelens/web-streams-polyfill
#     │   ├──  [16] https://github.com/nodeca/js-yaml
#     │   ├──  [17] https://github.com/ryanzim/universalify
#     │   ├──  [18] https://github.com/samn/json-stable-stringify
#     │   ├──  [19] https://github.com/sindresorhus/type-fest
#     │   ├──  [20] https://github.com/visionmedia/node-progress
#     ├
#     ├── https://github.com/prysmaticlabs/prysm
#     │   ├──  [1] https://github.com/cespare/xxhash
#     │   ├──  [2] https://github.com/deckarep/golang-set
#     │   ├──  [3] https://github.com/hashicorp/golang-lru
#     │   ├──  [4] https://github.com/libp2p/go-libp2p
#     │   ├──  [5] https://github.com/multiformats/go-multiaddr
#     │   ├──  [6] https://github.com/open-telemetry/opentelemetry-go
#     │   ├──  [7] https://github.com/prometheus/client_golang
#     │   ├──  [8] https://github.com/quic-go/quic-go
#     │   ├──  [9] https://github.com/supranational/blst
#     ├
#     ├── https://github.com/erigontech/erigon
#     │   ├──  [1] https://github.com/adraffy/ens-normalize.js
#     │   ├──  [2] https://github.com/cespare/xxhash
#     │   ├──  [3] https://github.com/crate-crypto/go-ipa
#     │   ├──  [4] https://github.com/deckarep/golang-set
#     │   ├──  [5] https://github.com/definitelytyped/definitelytyped
#     │   ├──  [6] https://github.com/ethers-io/ethers.js
#     │   ├──  [7] https://github.com/hashicorp/golang-lru
#     │   ├──  [8] https://github.com/libp2p/go-libp2p
#     │   ├──  [9] https://github.com/maticnetwork/crand
#     │   ├──  [10] https://github.com/microsoft/typescript
#     │   ├──  [11] https://github.com/multiformats/go-multiaddr
#     │   ├──  [12] https://github.com/open-telemetry/opentelemetry-go
#     │   ├──  [13] https://github.com/prometheus/client_golang
#     │   ├──  [14] https://github.com/quic-go/quic-go
#     │   ├──  [15] https://github.com/ricmoo/aes-js
#     │   ├──  [16] https://github.com/supranational/blst
#     │   ├──  [17] https://github.com/websockets/ws
#     ├
#     ├── https://github.com/web3/web3.js
#     │   ├──  [1] https://github.com/cryptocoinjs/secp256k1-node
#     │   ├──  [2] https://github.com/doowb/ansi-colors
#     │   ├──  [3] https://github.com/eslint/eslint
#     │   ├──  [4] https://github.com/fsevents/fsevents
#     │   ├──  [5] https://github.com/herumi/mcl-wasm
#     │   ├──  [6] https://github.com/inikulin/parse5
#     │   ├──  [7] https://github.com/jsbizon/node-memorystream
#     │   ├──  [8] https://github.com/jscommunity/make-error
#     │   ├──  [9] https://github.com/komagata/eastasianwidth
#     │   ├──  [10] https://github.com/marak/colors.js
#     │   ├──  [11] https://github.com/mccormicka/string-argv
#     │   ├──  [12] https://github.com/nodeca/js-yaml
#     │   ├──  [13] https://github.com/nodejs/node-gyp
#     │   ├──  [14] https://github.com/primus/eventemitter3
#     │   ├──  [15] https://github.com/raszi/node-tmp
#     │   ├──  [16] https://github.com/salesforce/tough-cookie
#     │   ├──  [17] https://github.com/shikijs/shiki
#     │   ├──  [18] https://github.com/syntax-tree/unist-util-visit
#     │   ├──  [19] https://github.com/watson/is-ci
#     │   ├──  [20] https://github.com/zertosh/invariant
#     ├
#     ├── https://github.com/grandinetech/grandine
#     │   ├──  [1] https://github.com/amanieu/parking_lot
#     │   ├──  [2] https://github.com/bheisler/criterion.rs
#     │   ├──  [3] https://github.com/enarx/ciborium
#     │   ├──  [4] https://github.com/ferrilab/ferrilab
#     │   ├──  [5] https://github.com/fusion-engineering/rust-git-version
#     │   ├──  [6] https://github.com/hickory-dns/hickory-dns
#     │   ├──  [7] https://github.com/hyperium/hyper
#     │   ├──  [8] https://github.com/jeltef/derive_more
#     │   ├──  [9] https://github.com/paritytech/jsonrpc
#     │   ├──  [10] https://github.com/peternator7/strum
#     │   ├──  [11] https://github.com/quinn-rs/quinn
#     │   ├──  [12] https://github.com/rusqlite/rusqlite
#     │   ├──  [13] https://github.com/rust-bitcoin/rust-secp256k1
#     │   ├──  [14] https://github.com/rust-lang/cargo
#     │   ├──  [15] https://github.com/rusticata/x509-parser
#     │   ├──  [16] https://github.com/rustwasm/wasm-bindgen
#     │   ├──  [17] https://github.com/servo/rust-smallvec
#     │   ├──  [18] https://github.com/supranational/blst
#     │   ├──  [19] https://github.com/toml-rs/toml
#     │   ├──  [20] https://github.com/tower-rs/tower
#     ├
#     ├── https://github.com/chainsafe/lodestar
#     │   ├──  [1] https://github.com/doowb/ansi-colors
#     │   ├──  [2] https://github.com/ethers-io/ethers.js
#     │   ├──  [3] https://github.com/fsevents/fsevents
#     │   ├──  [4] https://github.com/herumi/mcl-wasm
#     │   ├──  [5] https://github.com/inikulin/parse5
#     │   ├──  [6] https://github.com/jsbizon/node-memorystream
#     │   ├──  [7] https://github.com/jscommunity/make-error
#     │   ├──  [8] https://github.com/komagata/eastasianwidth
#     │   ├──  [9] https://github.com/kriskowal/asap
#     │   ├──  [10] https://github.com/mccormicka/string-argv
#     │   ├──  [11] https://github.com/nodeca/js-yaml
#     │   ├──  [12] https://github.com/nodejs/node-gyp
#     │   ├──  [13] https://github.com/primus/eventemitter3
#     │   ├──  [14] https://github.com/raszi/node-tmp
#     │   ├──  [15] https://github.com/salesforce/tough-cookie
#     │   ├──  [16] https://github.com/syntax-tree/unist-util-visit
#     │   ├──  [17] https://github.com/visionmedia/node-progress
#     │   ├──  [18] https://github.com/watson/is-ci
#     │   ├──  [19] https://github.com/wesleytodd/setprototypeof
#     │   ├──  [20] https://github.com/zertosh/invariant
#     ├
#     ├── https://github.com/sigp/lighthouse
#     │   ├──  [1] https://github.com/amanieu/parking_lot
#     │   ├──  [2] https://github.com/bheisler/criterion.rs
#     │   ├──  [3] https://github.com/diesel-rs/diesel
#     │   ├──  [4] https://github.com/ferrilab/ferrilab
#     │   ├──  [5] https://github.com/fusion-engineering/rust-git-version
#     │   ├──  [6] https://github.com/gakonst/ethers-rs
#     │   ├──  [7] https://github.com/gyscos/zstd-rs
#     │   ├──  [8] https://github.com/hickory-dns/hickory-dns
#     │   ├──  [9] https://github.com/jeltef/derive_more
#     │   ├──  [10] https://github.com/peternator7/strum
#     │   ├──  [11] https://github.com/quinn-rs/quinn
#     │   ├──  [12] https://github.com/recmo/uint
#     │   ├──  [13] https://github.com/rusqlite/rusqlite
#     │   ├──  [14] https://github.com/rust-fuzz/arbitrary
#     │   ├──  [15] https://github.com/rust-lang/cargo
#     │   ├──  [16] https://github.com/rusticata/x509-parser
#     │   ├──  [17] https://github.com/servo/rust-smallvec
#     │   ├──  [18] https://github.com/supranational/blst
#     │   ├──  [19] https://github.com/toml-rs/toml
#     │   ├──  [20] https://github.com/tower-rs/tower
#     ├
#     ├── https://github.com/ethereum/go-ethereum
#     │   ├──  [1] https://github.com/cespare/xxhash
#     │   ├──  [2] https://github.com/crate-crypto/go-ipa
#     │   ├──  [3] https://github.com/deckarep/golang-set
#     │   ├──  [4] https://github.com/prometheus/client_golang
#     │   ├──  [5] https://github.com/supranational/blst
#     ├
#     ├── https://github.com/status-im/nimbus-eth2
#     │   ├──  [1] https://github.com/numpy/numpy
#     │   ├──  [2] https://github.com/pandas-dev/pandas
#     ├
#     ├── https://github.com/ethereum/remix-project
#     │   ├──  [1] https://github.com/cryptocoinjs/secp256k1-node
#     │   ├──  [2] https://github.com/doowb/ansi-colors
#     │   ├──  [3] https://github.com/eslint/eslint
#     │   ├──  [4] https://github.com/flmnt/graphemer
#     │   ├──  [5] https://github.com/fsevents/fsevents
#     │   ├──  [6] https://github.com/herumi/mcl-wasm
#     │   ├──  [7] https://github.com/inikulin/parse5
#     │   ├──  [8] https://github.com/jscommunity/make-error
#     │   ├──  [9] https://github.com/komagata/eastasianwidth
#     │   ├──  [10] https://github.com/marak/colors.js
#     │   ├──  [11] https://github.com/mccormicka/string-argv
#     │   ├──  [12] https://github.com/nlkitai/nlux
#     │   ├──  [13] https://github.com/nodejs/node-gyp
#     │   ├──  [14] https://github.com/primus/eventemitter3
#     │   ├──  [15] https://github.com/raszi/node-tmp
#     │   ├──  [16] https://github.com/salesforce/tough-cookie
#     │   ├──  [17] https://github.com/syntax-tree/unist-util-visit
#     │   ├──  [18] https://github.com/visionmedia/node-progress
#     │   ├──  [19] https://github.com/watson/is-ci
#     │   ├──  [20] https://github.com/zertosh/invariant
#     ├
#     ├── https://github.com/safe-global/safe-smart-account
#     │   ├──  [1] https://github.com/alexei/sprintf.js
#     │   ├──  [2] https://github.com/ethereumjs/ethereumjs-monorepo
#     │   ├──  [3] https://github.com/gcanti/fp-ts
#     │   ├──  [4] https://github.com/jaredwray/keyv
#     │   ├──  [5] https://github.com/jshttp/http-errors
#     │   ├──  [6] https://github.com/komagata/eastasianwidth
#     │   ├──  [7] https://github.com/kpdecker/jsdiff
#     │   ├──  [8] https://github.com/kumavis/browser-stdout
#     │   ├──  [9] https://github.com/linusu/buffer-from
#     │   ├──  [10] https://github.com/lodash/lodash
#     │   ├──  [11] https://github.com/mafintosh/pump
#     │   ├──  [12] https://github.com/marak/colors.js
#     │   ├──  [13] https://github.com/mcollina/fastq
#     │   ├──  [14] https://github.com/prettier/prettier
#     │   ├──  [15] https://github.com/raynos/xtend
#     │   ├──  [16] https://github.com/rexxars/registry-auth-token
#     │   ├──  [17] https://github.com/ryanzim/universalify
#     │   ├──  [18] https://github.com/sc-forks/solidity-coverage
#     │   ├──  [19] https://github.com/wooorm/markdown-table
#     │   ├──  [20] https://github.com/yomguithereal/mnemonist
#     ├
#     ├── https://github.com/eth-infinitism/account-abstraction
#     │   ├──  [1] https://github.com/ethereumjs/ethereumjs-monorepo
#     │   ├──  [2] https://github.com/fent/ret.js
#     │   ├──  [3] https://github.com/gcanti/fp-ts
#     │   ├──  [4] https://github.com/herumi/mcl-wasm
#     │   ├──  [5] https://github.com/humanwhocodes/object-schema
#     │   ├──  [6] https://github.com/jaredwray/keyv
#     │   ├──  [7] https://github.com/jshttp/http-errors
#     │   ├──  [8] https://github.com/juanelas/bigint-crypto-utils
#     │   ├──  [9] https://github.com/kemitchell/validate-npm-package-license.js
#     │   ├──  [10] https://github.com/kumavis/browser-stdout
#     │   ├──  [11] https://github.com/linusu/buffer-from
#     │   ├──  [12] https://github.com/lodash/lodash
#     │   ├──  [13] https://github.com/mcollina/fastq
#     │   ├──  [14] https://github.com/prettier/prettier
#     │   ├──  [15] https://github.com/primus/eventemitter3
#     │   ├──  [16] https://github.com/raynos/xtend
#     │   ├──  [17] https://github.com/ryanzim/universalify
#     │   ├──  [18] https://github.com/sc-forks/solidity-coverage
#     │   ├──  [19] https://github.com/yarnpkg/yarn
#     │   ├──  [20] https://github.com/yomguithereal/mnemonist

# %% [markdown]
# # Export the graph to JSON

# %%
print("\nLevel 1 Nodes (Sources) and Their Summed Edge Weights:")
source_weights = validate_weights(G)
pd.Series(source_weights)
# Out:
# Level 1 Nodes (Sources) and Their Summed Edge Weights:
# https://github.com/ethereum/solidity                     0.000000
# https://github.com/vyperlang/vyper                       0.000000
# https://github.com/ethereum/py-evm                       0.200000
# https://github.com/ethereum/web3.py                      0.800000
# https://github.com/paradigmxyz/reth                      0.800000
# https://github.com/consensys/teku                        0.200000
# https://github.com/prysmaticlabs/prysm                   0.800000
# https://github.com/erigontech/erigon                     0.800000
# https://github.com/web3/web3.js                          0.800000
# https://github.com/grandinetech/grandine                 0.200000
# https://github.com/chainsafe/lodestar                    0.800000
# https://github.com/sigp/lighthouse                       0.771429
# https://github.com/ethereum/go-ethereum                  0.684211
# https://github.com/status-im/nimbus-eth2                 0.400000
# https://github.com/ethereum/remix-project                0.776471
# https://github.com/safe-global/safe-smart-account        0.800000
# https://github.com/eth-infinitism/account-abstraction    0.800000
# https://github.com/ethereumjs/ethereumjs-monorepo        0.785714
# dtype: float64

# %%
G_serializable = convert_graph_to_serializable(G)
graph_json = nx.node_link_data(G_serializable)
output_path = "../../graph/weighting_examples/oso_p2p_contributions_weighting.json"
with open(output_path, "w") as f:
    json.dump(graph_json, f, indent=2)
